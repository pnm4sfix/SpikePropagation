# %%
import sys
sys.path.insert(1, '../Python Scripts')
import poisson_simulation as ps

# %%
ps.multiple_simulation(False, False, 1.5e-2, True)
# Out:
# Min_idx length = 46
# New min_idx length = 46
# success rate is 100.0
# no waveforms
# Min_idx length = 42
# New min_idx length = 42
# success rate is 100.0
# no waveforms
# Min_idx length = 39
# New min_idx length = 38
# success rate is 97.43589743589743
# no waveforms
# Min_idx length = 34
# New min_idx length = 34
# success rate is 100.0
# no waveforms
# Min_idx length = 30
# New min_idx length = 30
# success rate is 96.66666666666667
# no waveforms
# Min_idx length = 45
# New min_idx length = 44
# success rate is 93.33333333333333
# no waveforms
# Min_idx length = 41
# New min_idx length = 40
# success rate is 95.1219512195122
# no waveforms
# Min_idx length = 37
# New min_idx length = 36
# success rate is 89.1891891891892
# no waveforms
# Min_idx length = 33
# New min_idx length = 32
# success rate is 96.96969696969697
# no waveforms
# Min_idx length = 31
# New min_idx length = 31
# success rate is 96.7741935483871
# no waveforms
# Min_idx length = 55
# New min_idx length = 54
# ...

# %%
ps.multiple_simulation(False, False, 0.5e-2, True)
# Out:
# Min_idx length = 42
# New min_idx length = 42
# success rate is 100.0
# no waveforms
# Min_idx length = 38
# New min_idx length = 37
# success rate is 97.36842105263158
# no waveforms
# Min_idx length = 34
# New min_idx length = 33
# success rate is 97.05882352941177
# no waveforms
# Min_idx length = 31
# New min_idx length = 30
# success rate is 96.7741935483871
# no waveforms
# Min_idx length = 28
# New min_idx length = 28
# success rate is 100.0
# no waveforms
# Min_idx length = 41
# New min_idx length = 41
# success rate is 100.0
# no waveforms
# Min_idx length = 37
# New min_idx length = 37
# success rate is 100.0
# no waveforms
# Min_idx length = 34
# New min_idx length = 33
# success rate is 97.05882352941177
# no waveforms
# Min_idx length = 29
# New min_idx length = 29
# success rate is 100.0
# no waveforms
# Min_idx length = 28
# New min_idx length = 27
# success rate is 96.42857142857143
# no waveforms
# Min_idx length = 41
# New min_idx length = 41
# ...
